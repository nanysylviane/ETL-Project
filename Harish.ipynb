# %%
# Dependencies
import requests
import json
import pymysql
#import mysql.connector
import pandas as pd

# %%
# Performing a GET Request and saving the
# API's response within a variable
url = "https://developer.nrel.gov/api/alt-fuel-stations/v1/nearest.json?api_key=0xRWZ5a51F0oHJp3kw8F1buaLGUIL7rz6pvfgwmr&location=Oklahoma_City+OK"
response = requests.get(url)
response_json = response.json()
type(response_json)

print(json.dumps(response_json, indent=4, sort_keys=True))

# connection = pymysql.connect(host='localhost',
#                             user='root',
#                             port=3306,
#                             password='admin',
#                             db='charging_stations')

# with connection.cursor() as cursor:
#        sqlQuery = "select * from charging_stations"
#        cursor.execute(sqlQuery)
# finally:
#    connection.close()
# Out:
# {
#     "fuel_stations": [
#         {
#             "access_code": "public",
#             "access_days_time": "24 hours daily",
#             "access_days_time_fr": null,
#             "access_detail_code": null,
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": null,
#             "city": "Oklahoma City",
#             "cng_dispenser_num": null,
#             "cng_fill_type_code": null,
#             "cng_psi": null,
#             "cng_renewable_source": null,
#             "cng_total_compression": null,
#             "cng_total_storage": null,
#             "cng_vehicle_class": null,
#             "country": "US",
#             "date_last_confirmed": "2019-05-18",
#             "distance": 0.24704,
#             "distance_km": 0.39757,
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": [
#                 "J1772"
#             ],
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": 2,
#             "ev_network": "ChargePoint Network",
#             "ev_network_ids": {
#                 "ports": [
#                     "1",
#                     "2"
#                 ],
#                 "posts": [
#                     "1:337591"
#                 ]
#             },
#             "ev_network_web": "http://www.chargepoint.com/",
#             "ev_other_evse": null,
#             "ev_pricing": "Pricing is based on length of time. $0 per hour for the first 2 hours, and $10 per additional hour",
#             "ev_pricing_fr": null,
#             "expected_date": null,
#             "facility_type": null,
#             "fuel_type_code": "ELEC",
#             "geocode_status": "GPS",
#             "groups_with_access_code": "Public",
#             "groups_with_access_code_fr": "Public",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 92274,
#             "intersection_directions": "LSQ P1; Parking Level 1",
#             "intersection_directions_fr": null,
#             "latitude": 35.4698872,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -97.5172284,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "ng_fill_type_code": null,
#             "ng_psi": null,
#             "ng_vehicle_class": null,
#             "open_date": null,
#             "owner_type_code": null,
#             "plus4": null,
#             "state": "OK",
#             "station_name": "P1 NORTH TOWER",
#             "station_phone": "888-758-4389",
#             "status_code": "E",
#             "street_address": "211 North Robinson",
#             "updated_at": "2019-05-18T09:07:48Z",
#             "zip": "73102"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "24 hours daily; for guest use only; see valet for access",
#             "access_days_time_fr": null,
#             "access_detail_code": null,
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": null,
#             "city": "Oklahoma City",
#             "cng_dispenser_num": null,
#             "cng_fill_type_code": null,
#             "cng_psi": null,
#             "cng_renewable_source": null,
#             "cng_total_compression": null,
#             "cng_total_storage": null,
#             "cng_vehicle_class": null,
#             "country": "US",
#             "date_last_confirmed": "2018-10-04",
#             "distance": 0.42329,
#             "distance_km": 0.68122,
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": [
#                 "J1772"
#             ],
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": 1,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": "Free",
#             "ev_pricing_fr": null,
#             "expected_date": null,
#             "facility_type": "HOTEL",
#             "fuel_type_code": "ELEC",
#             "geocode_status": "200-9",
#             "groups_with_access_code": "Public",
#             "groups_with_access_code_fr": "Public",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 72202,
#             "intersection_directions": null,
#             "intersection_directions_fr": null,
#             "latitude": 35.469145,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -97.513801,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "ng_fill_type_code": null,
#             "ng_psi": null,
#             "ng_vehicle_class": null,
#             "open_date": "2015-10-01",
#             "owner_type_code": "P",
#             "plus4": null,
#             "state": "OK",
#             "station_name": "The Skirvin Hilton",
#             "station_phone": "405-272-3040",
#             "status_code": "E",
#             "street_address": "1 Park Ave",
#             "updated_at": "2019-05-14T21:16:45Z",
#             "zip": "73102"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "24 hours daily",
#             "access_days_time_fr": null,
#             "access_detail_code": null,
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": null,
#             "city": "Oklahoma City",
#             "cng_dispenser_num": null,
#             "cng_fill_type_code": null,
#             "cng_psi": null,
#             "cng_renewable_source": null,
#             "cng_total_compression": null,
#             "cng_total_storage": null,
#             "cng_vehicle_class": null,
#             "country": "US",
#             "date_last_confirmed": "2019-05-18",
#             "distance": 0.51011,
#             "distance_km": 0.82094,
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": [
#                 "J1772"
#             ],
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": 2,
#             "ev_network": "ChargePoint Network",
#             "ev_network_ids": {
#                 "ports": [
#                     "1",
#                     "2"
#                 ],
#                 "posts": [
#                     "1:187343"
#                 ]
#             },
#             "ev_network_web": "http://www.chargepoint.com/",
#             "ev_other_evse": null,
#             "ev_pricing": "Free",
#             "ev_pricing_fr": null,
#             "expected_date": null,
#             "facility_type": null,
#             "fuel_type_code": "ELEC",
#             "geocode_status": "GPS",
#             "groups_with_access_code": "Public",
#             "groups_with_access_code_fr": "Public",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 88629,
#             "intersection_directions": "SANTA FE STATIO; North side Santa Fe Bldg. ",
#             "intersection_directions_fr": null,
#             "latitude": 35.4655993,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -97.5129402,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "ng_fill_type_code": null,
#             "ng_psi": null,
#             "ng_vehicle_class": null,
#             "open_date": null,
#             "owner_type_code": null,
#             "plus4": null,
#             "state": "OK",
#             "station_name": "OKLAHOMA CITY",
#             "station_phone": "888-758-4389",
#             "status_code": "E",
#             "street_address": "100 S E K Gaylord Blvd Bricktown",
#             "updated_at": "2019-05-18T09:07:48Z",
#             "zip": "73102"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "24 hours daily",
#             "access_days_time_fr": null,
#             "access_detail_code": "CREDIT_CARD_ALWAYS",
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": "A M V Voyager Wright_Exp",
#             "city": "Oklahoma City",
#             "cng_dispenser_num": null,
#             "cng_fill_type_code": null,
#             "cng_psi": null,
#             "cng_renewable_source": null,
#             "cng_total_compression": null,
#             "cng_total_storage": null,
#             "cng_vehicle_class": null,
#             "country": "US",
#             "date_last_confirmed": "2018-09-10",
#             "distance": 0.60939,
#             "distance_km": 0.98072,
#             "e85_blender_pump": false,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "expected_date": null,
#             "facility_type": "STANDALONE_STATION",
#             "fuel_type_code": "E85",
#             "geocode_status": "200-9",
#             "groups_with_access_code": "Public - Credit card at all times",
#             "groups_with_access_code_fr": "Public - Carte de cr\u00e9dit en tout temps",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 21967,
#             "intersection_directions": "At Harrison Ave",
#             "intersection_directions_fr": null,
#             "latitude": 35.471983,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -97.511336,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "ng_fill_type_code": null,
#             "ng_psi": null,
#             "ng_vehicle_class": null,
#             "open_date": "2008-04-15",
#             "owner_type_code": "P",
#             "plus4": null,
#             "state": "OK",
#             "station_name": "Conoco",
#             "station_phone": "405-677-3373",
#             "status_code": "E",
#             "street_address": "21 NE 4th St",
#             "updated_at": "2019-05-14T21:16:45Z",
#             "zip": "73104"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "7am-7pm M-Th and Sat, 7am-8pm F, 9am-5pm Sun",
#             "access_days_time_fr": null,
#             "access_detail_code": null,
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": "A Cash D M V",
#             "city": "Oklahoma City",
#             "cng_dispenser_num": null,
#             "cng_fill_type_code": null,
#             "cng_psi": null,
#             "cng_renewable_source": null,
#             "cng_total_compression": null,
#             "cng_total_storage": null,
#             "cng_vehicle_class": null,
#             "country": "US",
#             "date_last_confirmed": "2018-09-10",
#             "distance": 0.69272,
#             "distance_km": 1.11482,
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "expected_date": null,
#             "facility_type": "RENTAL_CAR_RETURN",
#             "fuel_type_code": "LPG",
#             "geocode_status": "200-9",
#             "groups_with_access_code": "Public",
#             "groups_with_access_code_fr": "Public",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 69624,
#             "intersection_directions": null,
#             "intersection_directions_fr": null,
#             "latitude": 35.4633,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -97.51075,
#             "lpg_nozzle_types": null,
#             "lpg_primary": false,
#             "ng_fill_type_code": null,
#             "ng_psi": null,
#             "ng_vehicle_class": null,
#             "open_date": null,
#             "owner_type_code": "P",
#             "plus4": null,
#             "state": "OK",
#             "station_name": "U-Haul",
#             "station_phone": "405-235-9446",
#             "status_code": "E",
#             "street_address": "100 2nd St SE",
#             "updated_at": "2019-05-14T21:16:45Z",
#             "zip": "73129"
#         },
#         {
#             "access_code": "private",
#             "access_days_time": null,
#             "access_days_time_fr": null,
#             "access_detail_code": "GOVERNMENT",
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": null,
#             "city": "Oklahoma City",
#             "cng_dispenser_num": null,
#             "cng_fill_type_code": "T",
#             "cng_psi": "3000",
#             "cng_renewable_source": null,
#             "cng_total_compression": 50,
#             "cng_total_storage": null,
#             "cng_vehicle_class": "MD",
#             "country": "US",
#             "date_last_confirmed": "2018-08-07",
#             "distance": 1.75183,
#             "distance_km": 2.8193,
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "expected_date": null,
#             "facility_type": "MUNI_GOV",
#             "fuel_type_code": "CNG",
#             "geocode_status": "200-9",
#             "groups_with_access_code": "Private - Government only",
#             "groups_with_access_code_fr": "Priv\u00e9 - R\u00e9serv\u00e9 au gouvernement",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 735,
#             "intersection_directions": null,
#             "intersection_directions_fr": null,
#             "latitude": 35.473122,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -97.551807,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "ng_fill_type_code": "T",
#             "ng_psi": "3000",
#             "ng_vehicle_class": "MD",
#             "open_date": "1996-12-15",
#             "owner_type_code": "LG",
#             "plus4": null,
#             "state": "OK",
#             "station_name": "City of Oklahoma City",
#             "station_phone": null,
#             "status_code": "E",
#             "street_address": "621 N Pennsylvania Ave",
#             "updated_at": "2019-05-14T21:16:45Z",
#             "zip": "73107"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "24 hours daily",
#             "access_days_time_fr": null,
#             "access_detail_code": null,
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": "A ARI Cash Checks D Debit FuelMan M Proprietor V Voyager Wright_Exp",
#             "city": "Oklahoma City",
#             "cng_dispenser_num": 2,
#             "cng_fill_type_code": "Q",
#             "cng_psi": "3600",
#             "cng_renewable_source": null,
#             "cng_total_compression": 257,
#             "cng_total_storage": null,
#             "cng_vehicle_class": "HD",
#             "country": "US",
#             "date_last_confirmed": "2019-01-10",
#             "distance": 1.84618,
#             "distance_km": 2.97114,
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "expected_date": null,
#             "facility_type": "CONVENIENCE_STORE",
#             "fuel_type_code": "CNG",
#             "geocode_status": "200-9",
#             "groups_with_access_code": "Public",
#             "groups_with_access_code_fr": "Public",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 36592,
#             "intersection_directions": "NW 23rd St at Santa Fe.",
#             "intersection_directions_fr": null,
#             "latitude": 35.494079,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -97.511596,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "ng_fill_type_code": "Q",
#             "ng_psi": "3600",
#             "ng_vehicle_class": "HD",
#             "open_date": "2011-01-15",
#             "owner_type_code": "P",
#             "plus4": null,
#             "state": "OK",
#             "station_name": "OnCue Express #101 - C-Store",
#             "station_phone": "405-557-1170",
#             "status_code": "E",
#             "street_address": "1 NW 23rd St",
#             "updated_at": "2019-05-14T21:16:45Z",
#             "zip": "73103"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "24 hours daily",
#             "access_days_time_fr": null,
#             "access_detail_code": null,
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": "A Cash Checks Comdata D Debit FuelMan M V Voyager Wright_Exp",
#             "city": "Oklahoma City",
#             "cng_dispenser_num": null,
#             "cng_fill_type_code": null,
#             "cng_psi": null,
#             "cng_renewable_source": null,
#             "cng_total_compression": null,
#             "cng_total_storage": null,
#             "cng_vehicle_class": null,
#             "country": "US",
#             "date_last_confirmed": "2019-01-10",
#             "distance": 1.84618,
#             "distance_km": 2.97114,
#             "e85_blender_pump": false,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "expected_date": null,
#             "facility_type": "CONVENIENCE_STORE",
#             "fuel_type_code": "E85",
#             "geocode_status": "200-9",
#             "groups_with_access_code": "Public",
#             "groups_with_access_code_fr": "Public",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 105463,
#             "intersection_directions": "NW 23rd St at Santa Fe.",
#             "intersection_directions_fr": null,
#             "latitude": 35.494079,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -97.511596,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "ng_fill_type_code": null,
#             "ng_psi": null,
#             "ng_vehicle_class": null,
#             "open_date": "2018-12-15",
#             "owner_type_code": "P",
#             "plus4": null,
#             "state": "OK",
#             "station_name": "OnCue Express #101 - C-Store",
#             "station_phone": "405-557-1170",
#             "status_code": "E",
#             "street_address": "1 NW 23rd St",
#             "updated_at": "2019-05-14T21:16:45Z",
#             "zip": "73103"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "24 hours daily",
#             "access_days_time_fr": null,
#             "access_detail_code": null,
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": "Cash Checks M V",
#             "city": "Oklahoma City",
#             "cng_dispenser_num": 2,
#             "cng_fill_type_code": "Q",
#             "cng_psi": "3600",
#             "cng_renewable_source": null,
#             "cng_total_compression": null,
#             "cng_total_storage": null,
#             "cng_vehicle_class": "MD",
#             "country": "US",
#             "date_last_confirmed": "2019-02-06",
#             "distance": 2.81099,
#             "distance_km": 4.52385,
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "expected_date": null,
#             "facility_type": "CONVENIENCE_STORE",
#             "fuel_type_code": "CNG",
#             "geocode_status": "200-9",
#             "groups_with_access_code": "Public",
#             "groups_with_access_code_fr": "Public",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 71474,
#             "intersection_directions": "NE 36th & Santa Fe",
#             "intersection_directions_fr": null,
#             "latitude": 35.508446,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -97.511304,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "ng_fill_type_code": "Q",
#             "ng_psi": "3600",
#             "ng_vehicle_class": "MD",
#             "open_date": "2016-10-27",
#             "owner_type_code": "P",
#             "plus4": null,
#             "state": "OK",
#             "station_name": "7-Eleven #23",
#             "station_phone": "405-208-4401",
#             "status_code": "E",
#             "street_address": "1 NE 36th St",
#             "updated_at": "2019-05-14T21:16:45Z",
#             "zip": "73105"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "24 hours daily",
#             "access_days_time_fr": null,
#             "access_detail_code": null,
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": null,
#             "city": "Oklahoma City",
#             "cng_dispenser_num": null,
#             "cng_fill_type_code": null,
#             "cng_psi": null,
#             "cng_renewable_source": null,
#             "cng_total_compression": null,
#             "cng_total_storage": null,
#             "cng_vehicle_class": null,
#             "country": "US",
#             "date_last_confirmed": "2018-06-05",
#             "distance": 3.23762,
#             "distance_km": 5.21044,
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": [
#                 "CHADEMO",
#                 "J1772"
#             ],
#             "ev_dc_fast_num": 1,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": 2,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": "Free",
#             "ev_pricing_fr": null,
#             "expected_date": null,
#             "facility_type": "OFFICE_BLDG",
#             "fuel_type_code": "ELEC",
#             "geocode_status": "200-8",
#             "groups_with_access_code": "Public",
#             "groups_with_access_code_fr": "Public",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 96937,
#             "intersection_directions": null,
#             "intersection_directions_fr": null,
#             "latitude": 35.514833,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -97.51194,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "ng_fill_type_code": null,
#             "ng_psi": null,
#             "ng_vehicle_class": null,
#             "open_date": "2016-01-01",
#             "owner_type_code": "P",
#             "plus4": null,
#             "state": "OK",
#             "station_name": "Spiers New Technologies",
#             "station_phone": "405-605-8066",
#             "status_code": "E",
#             "street_address": "50 NE 42nd St",
#             "updated_at": "2019-05-14T21:16:45Z",
#             "zip": "73105"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "24 hours daily",
#             "access_days_time_fr": null,
#             "access_detail_code": null,
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": "A Cash Checks D Debit M V Voyager Wright_Exp",
#             "city": "Oklahoma City",
#             "cng_dispenser_num": null,
#             "cng_fill_type_code": null,
#             "cng_psi": null,
#             "cng_renewable_source": null,
#             "cng_total_compression": null,
#             "cng_total_storage": null,
#             "cng_vehicle_class": null,
#             "country": "US",
#             "date_last_confirmed": "2018-09-10",
#             "distance": 3.34624,
#             "distance_km": 5.38525,
#             "e85_blender_pump": false,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "expected_date": null,
#             "facility_type": "CONVENIENCE_STORE",
#             "fuel_type_code": "E85",
#             "geocode_status": "200-9",
#             "groups_with_access_code": "Public",
#             "groups_with_access_code_fr": "Public",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 91925,
#             "intersection_directions": null,
#             "intersection_directions_fr": null,
#             "latitude": 35.42105,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -97.508741,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "ng_fill_type_code": null,
#             "ng_psi": null,
#             "ng_vehicle_class": null,
#             "open_date": "2018-01-15",
#             "owner_type_code": "P",
#             "plus4": null,
#             "state": "OK",
#             "station_name": "OnCue Express #113",
#             "station_phone": "405-632-0284",
#             "status_code": "E",
#             "street_address": "4413 S Shields Blvd",
#             "updated_at": "2019-05-14T21:16:45Z",
#             "zip": "73129"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "24 hours daily",
#             "access_days_time_fr": null,
#             "access_detail_code": "CREDIT_CARD_ALWAYS",
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": "A D GasCard M V Voyager Wright_Exp",
#             "city": "Oklahoma City",
#             "cng_dispenser_num": 2,
#             "cng_fill_type_code": "Q",
#             "cng_psi": "3600",
#             "cng_renewable_source": null,
#             "cng_total_compression": null,
#             "cng_total_storage": null,
#             "cng_vehicle_class": "HD",
#             "country": "US",
#             "date_last_confirmed": "2018-09-10",
#             "distance": 3.55082,
#             "distance_km": 5.71449,
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "expected_date": null,
#             "facility_type": "CONVENIENCE_STORE",
#             "fuel_type_code": "CNG",
#             "geocode_status": "200-9",
#             "groups_with_access_code": "Public - Credit card at all times",
#             "groups_with_access_code_fr": "Public - Carte de cr\u00e9dit en tout temps",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 44752,
#             "intersection_directions": "Reno Ave and N Portland Ave",
#             "intersection_directions_fr": null,
#             "latitude": 35.464849,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -97.584064,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "ng_fill_type_code": "Q",
#             "ng_psi": "3600",
#             "ng_vehicle_class": "HD",
#             "open_date": "2011-12-31",
#             "owner_type_code": "P",
#             "plus4": null,
#             "state": "OK",
#             "station_name": "Conoco - Reno Partners",
#             "station_phone": "405-942-7528",
#             "status_code": "E",
#             "street_address": "3701 W Reno Ave",
#             "updated_at": "2019-05-14T21:16:45Z",
#             "zip": "73107"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "24 hours daily",
#             "access_days_time_fr": null,
#             "access_detail_code": null,
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": "A Cash Checks D Debit M V Voyager Wright_Exp",
#             "city": "Oklahoma City",
#             "cng_dispenser_num": null,
#             "cng_fill_type_code": null,
#             "cng_psi": null,
#             "cng_renewable_source": null,
#             "cng_total_compression": null,
#             "cng_total_storage": null,
#             "cng_vehicle_class": null,
#             "country": "US",
#             "date_last_confirmed": "2018-09-10",
#             "distance": 3.59466,
#             "distance_km": 5.78504,
#             "e85_blender_pump": false,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "expected_date": null,
#             "facility_type": "CONVENIENCE_STORE",
#             "fuel_type_code": "E85",
#             "geocode_status": "200-9",
#             "groups_with_access_code": "Public",
#             "groups_with_access_code_fr": "Public",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 91929,
#             "intersection_directions": null,
#             "intersection_directions_fr": null,
#             "latitude": 35.479026,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -97.583691,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "ng_fill_type_code": null,
#             "ng_psi": null,
#             "ng_vehicle_class": null,
#             "open_date": "2018-01-15",
#             "owner_type_code": "P",
#             "plus4": null,
#             "state": "OK",
#             "station_name": "OnCue Express #125",
#             "station_phone": "405-948-3325",
#             "status_code": "E",
#             "street_address": "1001 N Portland Ave",
#             "updated_at": "2019-05-14T21:16:45Z",
#             "zip": "73107"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "8am-5pm M-F",
#             "access_days_time_fr": null,
#             "access_detail_code": null,
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": "A Cash D M V",
#             "city": "Oklahoma City",
#             "cng_dispenser_num": null,
#             "cng_fill_type_code": null,
#             "cng_psi": null,
#             "cng_renewable_source": null,
#             "cng_total_compression": null,
#             "cng_total_storage": null,
#             "cng_vehicle_class": null,
#             "country": "US",
#             "date_last_confirmed": "2018-09-10",
#             "distance": 3.6097,
#             "distance_km": 5.80925,
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "expected_date": null,
#             "facility_type": "FUEL_RESELLER",
#             "fuel_type_code": "LPG",
#             "geocode_status": "200-9",
#             "groups_with_access_code": "Public",
#             "groups_with_access_code_fr": "Public",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 35764,
#             "intersection_directions": null,
#             "intersection_directions_fr": null,
#             "latitude": 35.472783,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -97.585054,
#             "lpg_nozzle_types": null,
#             "lpg_primary": false,
#             "ng_fill_type_code": null,
#             "ng_psi": null,
#             "ng_vehicle_class": null,
#             "open_date": null,
#             "owner_type_code": "P",
#             "plus4": null,
#             "state": "OK",
#             "station_name": "Pinnacle Propane",
#             "station_phone": "405-917-1850",
#             "status_code": "E",
#             "street_address": "601 N Portland Ave",
#             "updated_at": "2019-05-14T21:16:45Z",
#             "zip": "73107"
#         },
#         {
#             "access_code": "private",
#             "access_days_time": null,
#             "access_days_time_fr": null,
#             "access_detail_code": null,
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": null,
#             "city": "Oklahoma City",
#             "cng_dispenser_num": null,
#             "cng_fill_type_code": "B",
#             "cng_psi": "3600",
#             "cng_renewable_source": null,
#             "cng_total_compression": 250,
#             "cng_total_storage": 33000,
#             "cng_vehicle_class": "MD",
#             "country": "US",
#             "date_last_confirmed": "2018-08-07",
#             "distance": 3.63945,
#             "distance_km": 5.85713,
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "expected_date": null,
#             "facility_type": "UTILITY",
#             "fuel_type_code": "CNG",
#             "geocode_status": "200-9",
#             "groups_with_access_code": "Private",
#             "groups_with_access_code_fr": "Priv\u00e9",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 739,
#             "intersection_directions": null,
#             "intersection_directions_fr": null,
#             "latitude": 35.520864,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -97.51313,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "ng_fill_type_code": "B",
#             "ng_psi": "3600",
#             "ng_vehicle_class": "MD",
#             "open_date": "1996-12-15",
#             "owner_type_code": "T",
#             "plus4": null,
#             "state": "OK",
#             "station_name": "Oklahoma Natural Gas - Northside Service Center",
#             "station_phone": null,
#             "status_code": "E",
#             "street_address": "4901 N Santa Fe Ave",
#             "updated_at": "2019-05-14T21:16:45Z",
#             "zip": "73118"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "24 hours daily",
#             "access_days_time_fr": null,
#             "access_detail_code": "CREDIT_CARD_ALWAYS",
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": "FuelMan M V Voyager Wright_Exp",
#             "city": "Oklahoma City",
#             "cng_dispenser_num": 2,
#             "cng_fill_type_code": "Q",
#             "cng_psi": "3600",
#             "cng_renewable_source": null,
#             "cng_total_compression": 1000,
#             "cng_total_storage": null,
#             "cng_vehicle_class": "HD",
#             "country": "US",
#             "date_last_confirmed": "2018-09-10",
#             "distance": 3.65852,
#             "distance_km": 5.88782,
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "expected_date": null,
#             "facility_type": "CONVENIENCE_STORE",
#             "fuel_type_code": "CNG",
#             "geocode_status": "200-9",
#             "groups_with_access_code": "Public - Credit card at all times",
#             "groups_with_access_code_fr": "Public - Carte de cr\u00e9dit en tout temps",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 73696,
#             "intersection_directions": "NW 36th St & N May Ave",
#             "intersection_directions_fr": null,
#             "latitude": 35.507948,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -97.564657,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "ng_fill_type_code": "Q",
#             "ng_psi": "3600",
#             "ng_vehicle_class": "HD",
#             "open_date": "2016-03-31",
#             "owner_type_code": "P",
#             "plus4": null,
#             "state": "OK",
#             "station_name": "OnCue Express #119 - C-Store",
#             "station_phone": "405-338-8552",
#             "status_code": "E",
#             "street_address": "2837 NW 36th St",
#             "updated_at": "2019-05-14T21:16:45Z",
#             "zip": "73112"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "24 hours daily",
#             "access_days_time_fr": null,
#             "access_detail_code": null,
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": "A Cash Checks D Debit FleetOne FuelMan M V Voyager Wright_Exp",
#             "city": "Oklahoma City",
#             "cng_dispenser_num": null,
#             "cng_fill_type_code": null,
#             "cng_psi": null,
#             "cng_renewable_source": null,
#             "cng_total_compression": null,
#             "cng_total_storage": null,
#             "cng_vehicle_class": null,
#             "country": "US",
#             "date_last_confirmed": "2018-09-10",
#             "distance": 3.65852,
#             "distance_km": 5.88782,
#             "e85_blender_pump": false,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "expected_date": null,
#             "facility_type": "CONVENIENCE_STORE",
#             "fuel_type_code": "E85",
#             "geocode_status": "200-9",
#             "groups_with_access_code": "Public",
#             "groups_with_access_code_fr": "Public",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 102564,
#             "intersection_directions": "NW 36th St & N May Ave",
#             "intersection_directions_fr": null,
#             "latitude": 35.507948,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -97.564657,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "ng_fill_type_code": null,
#             "ng_psi": null,
#             "ng_vehicle_class": null,
#             "open_date": "2018-08-15",
#             "owner_type_code": "P",
#             "plus4": null,
#             "state": "OK",
#             "station_name": "OnCue Express #119 - C-Store",
#             "station_phone": "405-338-8552",
#             "status_code": "E",
#             "street_address": "2837 NW 36th St",
#             "updated_at": "2019-05-14T21:16:45Z",
#             "zip": "73112"
#         },
#         {
#             "access_code": "private",
#             "access_days_time": null,
#             "access_days_time_fr": null,
#             "access_detail_code": null,
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": null,
#             "city": "Oklahoma City",
#             "cng_dispenser_num": null,
#             "cng_fill_type_code": "Q",
#             "cng_psi": "3000 3600",
#             "cng_renewable_source": null,
#             "cng_total_compression": 500,
#             "cng_total_storage": null,
#             "cng_vehicle_class": "MD",
#             "country": "US",
#             "date_last_confirmed": "2018-08-07",
#             "distance": 3.71842,
#             "distance_km": 5.98422,
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "expected_date": null,
#             "facility_type": "FLEET_GARAGE",
#             "fuel_type_code": "CNG",
#             "geocode_status": "200-9",
#             "groups_with_access_code": "Private",
#             "groups_with_access_code_fr": "Priv\u00e9",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 737,
#             "intersection_directions": null,
#             "intersection_directions_fr": null,
#             "latitude": 35.455709,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -97.585311,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "ng_fill_type_code": "Q",
#             "ng_psi": "3000 3600",
#             "ng_vehicle_class": "MD",
#             "open_date": "1996-12-15",
#             "owner_type_code": "P",
#             "plus4": null,
#             "state": "OK",
#             "station_name": "United Parcel Service",
#             "station_phone": null,
#             "status_code": "E",
#             "street_address": "901 S Portland Ave",
#             "updated_at": "2019-05-14T21:16:45Z",
#             "zip": "73108"
#         },
#         {
#             "access_code": "private",
#             "access_days_time": null,
#             "access_days_time_fr": null,
#             "access_detail_code": "GOVERNMENT",
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": null,
#             "city": "Oklahoma City",
#             "cng_dispenser_num": null,
#             "cng_fill_type_code": "B",
#             "cng_psi": "3600",
#             "cng_renewable_source": null,
#             "cng_total_compression": null,
#             "cng_total_storage": null,
#             "cng_vehicle_class": "HD",
#             "country": "US",
#             "date_last_confirmed": "2018-10-04",
#             "distance": 3.9678,
#             "distance_km": 6.38556,
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "expected_date": null,
#             "facility_type": "MUNI_GOV",
#             "fuel_type_code": "CNG",
#             "geocode_status": "200-9",
#             "groups_with_access_code": "Private - Government only",
#             "groups_with_access_code_fr": "Priv\u00e9 - R\u00e9serv\u00e9 au gouvernement",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 33117,
#             "intersection_directions": "At Portland Ave.",
#             "intersection_directions_fr": null,
#             "latitude": 35.445459,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -97.585727,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "ng_fill_type_code": "B",
#             "ng_psi": "3600",
#             "ng_vehicle_class": "HD",
#             "open_date": "2006-06-15",
#             "owner_type_code": "LG",
#             "plus4": null,
#             "state": "OK",
#             "station_name": "City of Oklahoma City - Central Maintenance Facility",
#             "station_phone": null,
#             "status_code": "E",
#             "street_address": "3738 SW 15th St",
#             "updated_at": "2019-05-14T21:16:45Z",
#             "zip": "73108"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "7am-7pm M-Th and Sat, 7am-8pm F, 9am-5pm Sun",
#             "access_days_time_fr": null,
#             "access_detail_code": null,
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": "A Cash D M V",
#             "city": "Oklahoma City",
#             "cng_dispenser_num": null,
#             "cng_fill_type_code": null,
#             "cng_psi": null,
#             "cng_renewable_source": null,
#             "cng_total_compression": null,
#             "cng_total_storage": null,
#             "cng_vehicle_class": null,
#             "country": "US",
#             "date_last_confirmed": "2018-09-10",
#             "distance": 4.04476,
#             "distance_km": 6.50941,
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "expected_date": null,
#             "facility_type": "RENTAL_CAR_RETURN",
#             "fuel_type_code": "LPG",
#             "geocode_status": "200-9",
#             "groups_with_access_code": "Public",
#             "groups_with_access_code_fr": "Public",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 69625,
#             "intersection_directions": null,
#             "intersection_directions_fr": null,
#             "latitude": 35.507159,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -97.467311,
#             "lpg_nozzle_types": null,
#             "lpg_primary": false,
#             "ng_fill_type_code": null,
#             "ng_psi": null,
#             "ng_vehicle_class": null,
#             "open_date": null,
#             "owner_type_code": "P",
#             "plus4": null,
#             "state": "OK",
#             "station_name": "U-Haul",
#             "station_phone": "405-424-5442",
#             "status_code": "E",
#             "street_address": "2500 36th St NE",
#             "updated_at": "2019-05-14T21:16:45Z",
#             "zip": "73111"
#         }
#     ],
#     "latitude": 35.468494,
#     "location_country": "US",
#     "longitude": -97.521264,
#     "offset": 0,
#     "precision": {
#         "name": "locality",
#         "types": [
#             "locality",
#             "political"
#         ],
#         "value": 4
#     },
#     "station_counts": {
#         "fuels": {
#             "BD": {
#                 "total": 0
#             },
#             "CNG": {
#                 "total": 9
#             },
#             "E85": {
#                 "total": 5
#             },
#             "ELEC": {
#                 "stations": {
#                     "total": 6
#                 },
#                 "total": 14
#             },
#             "HY": {
#                 "total": 0
#             },
#             "LNG": {
#                 "total": 0
#             },
#             "LPG": {
#                 "total": 5
#             }
#         },
#         "total": 33
#     },
#     "station_locator_url": "http://www.afdc.energy.gov/afdc/locator/stations/",
#     "total_results": 25
# }

# %%
# CREATE TABLE `charging_stations` (
#  `access_code` varchar(64) default NULL,
#  `city` varchar(64) DEFAULT NULL,
#  `ev_dc_fast_num` varchar(64) DEFAULT NULL,
#  `ev_level1_evse_num` varchar(64) DEFAULT NULL,
#  `ev_level2_evse_num` varchar(64) DEFAULT NULL,
#  `ev_network` varchar(64) DEFAULT NULL,
#  `ev_network_web` varchar(64) DEFAULT NULL,
#  `ev_pricing` varchar(1024) DEFAULT NULL,
#  `fuel_type_code` varchar(64) DEFAULT NULL,
#  `geocode_status` varchar(64) DEFAULT NULL,
#  `groups_with_access_code` varchar(64) DEFAULT NULL,
#  `id` varchar(64) DEFAULT NULL,
#  `intersection_directions` varchar(64) DEFAULT NULL,
#  `latitude` varchar(64) DEFAULT NULL,
#  `longitude` varchar(64) DEFAULT NULL,
#  `state` varchar(64) DEFAULT NULL,
#  `station_name` varchar(64) DEFAULT NULL,
#  `station_phone` varchar(64) DEFAULT NULL,
#  `status_code` varchar(64) DEFAULT NULL,
#  `street_address` varchar(64) DEFAULT NULL,
#  `zip` varchar(64) DEFAULT NULL
# );

# %%
import pymysql

conn = pymysql.connect(host='localhost',
                            user='root',
                            port=3306,
                            password='password',
                            db='chargingS_dealers')
mycursor = conn.cursor()

fuel_stations = response_json["fuel_stations"]

# fuel_stations_dict = response_json["fuel_stations"]
# print(type(fuel_stations_dict))

df = pd.DataFrame(fuel_stations)
df


# iterate over rows with iterrows()
for index, row in df.iterrows():
     # access data using column names
    #print(index, row['access_code'], row['city'], row['ev_dc_fast_num'])
    
    access_code = row['access_code']
    city = row['city']
    ev_level1_evse_num = row['ev_level1_evse_num']
    ev_level2_evse_num = row['ev_level2_evse_num']
    ev_network = row['ev_network']
    ev_network_web = row['ev_network_web']
    ev_pricing = row['ev_pricing']
    fuel_type_code = row['fuel_type_code']
    geocode_status = row['geocode_status']
    groups_with_access_code = row['groups_with_access_code']
    intersection_directions = row['intersection_directions']
    latitude = row['latitude']
    longitude = row['longitude']
    state = row['state']
    id = row['id']
    station_name = row['station_name']
    station_phone = row['station_phone']
    status_code = row['status_code']
    street_address = row['street_address']
    zip = row['zip']
    
    #stringVal1 =  "'" + access_code + "','" + str(city) + "','" +  str(ev_level1_evse_num) + "','" 
#     print(stringVal1)

    stringVal =  "'" + str(access_code) + "'," + "'" + str(city) + "','" +  str(ev_level1_evse_num) + "','" + str(ev_level2_evse_num) + "','" +   str(ev_network) + "','" +   str(ev_network_web) + "','" +  str(ev_pricing) + "','" +   str(fuel_type_code) + "','" +   str(geocode_status) + "','" +  str(groups_with_access_code) + "','" +   str(intersection_directions) + "','" +   str(latitude) + "','" +   str(longitude) + "','" +  str(state) + "','" +  str(id) + "','" +  str(station_name) + "','" +  str(station_phone) + "','" +  str(status_code) + "','" +  str(street_address) + "','" +  str(zip) + "')" 
    #print(stringVal)
    
    sql = "INSERT INTO charging_stations(access_code, city, ev_level1_evse_num, ev_level2_evse_num, ev_network, ev_network_web, ev_pricing, fuel_type_code, geocode_status, groups_with_access_code, intersection_directions, latitude, longitude, state, id, station_name, station_phone, status_code, street_address, zip) VALUES("
    sql = sql + stringVal
    print(sql)
    try :
        mycursor.execute(sql)
        conn.commit()
    except :
        conn.rollback()
# Out:
# INSERT INTO charging_stations(access_code, city, ev_level1_evse_num, ev_level2_evse_num, ev_network, ev_network_web, ev_pricing, fuel_type_code, geocode_status, groups_with_access_code, intersection_directions, latitude, longitude, state, id, station_name, station_phone, status_code, street_address, zip) VALUES('public','Oklahoma City','None','2.0','ChargePoint Network','http://www.chargepoint.com/','Pricing is based on length of time. $0 per hour for the first 2 hours, and $10 per additional hour','ELEC','GPS','Public','LSQ P1; Parking Level 1','35.4698872','-97.5172284','OK','92274','P1 NORTH TOWER','888-758-4389','E','211 North Robinson','73102')
# INSERT INTO charging_stations(access_code, city, ev_level1_evse_num, ev_level2_evse_num, ev_network, ev_network_web, ev_pricing, fuel_type_code, geocode_status, groups_with_access_code, intersection_directions, latitude, longitude, state, id, station_name, station_phone, status_code, street_address, zip) VALUES('public','Oklahoma City','None','1.0','None','None','Free','ELEC','200-9','Public','None','35.469145','-97.513801','OK','72202','The Skirvin Hilton','405-272-3040','E','1 Park Ave','73102')
# INSERT INTO charging_stations(access_code, city, ev_level1_evse_num, ev_level2_evse_num, ev_network, ev_network_web, ev_pricing, fuel_type_code, geocode_status, groups_with_access_code, intersection_directions, latitude, longitude, state, id, station_name, station_phone, status_code, street_address, zip) VALUES('public','Oklahoma City','None','2.0','ChargePoint Network','http://www.chargepoint.com/','Free','ELEC','GPS','Public','SANTA FE STATIO; North side Santa Fe Bldg. ','35.4655993','-97.5129402','OK','88629','OKLAHOMA CITY','888-758-4389','E','100 S E K Gaylord Blvd Bricktown','73102')
# INSERT INTO charging_stations(access_code, city, ev_level1_evse_num, ev_level2_evse_num, ev_network, ev_network_web, ev_pricing, fuel_type_code, geocode_status, groups_with_access_code, intersection_directions, latitude, longitude, state, id, station_name, station_phone, status_code, street_address, zip) VALUES('public','Oklahoma City','None','nan','None','None','None','E85','200-9','Public - Credit card at all times','At Harrison Ave','35.471983','-97.511336','OK','21967','Conoco','405-677-3373','E','21 NE 4th St','73104')
# INSERT INTO charging_stations(access_code, city, ev_level1_evse_num, ev_level2_evse_num, ev_network, ev_network_web, ev_pricing, fuel_type_code, geocode_status, groups_with_access_code, intersection_directions, latitude, longitude, state, id, station_name, station_phone, status_code, street_address, zip) VALUES('public','Oklahoma City','None','nan','None','None','None','LPG','200-9','Public','None','35.4633','-97.51075','OK','69624','U-Haul','405-235-9446','E','100 2nd St SE','73129')
# INSERT INTO charging_stations(access_code, city, ev_level1_evse_num, ev_level2_evse_num, ev_network, ev_network_web, ev_pricing, fuel_type_code, geocode_status, groups_with_access_code, intersection_directions, latitude, longitude, state, id, station_name, station_phone, status_code, street_address, zip) VALUES('private','Oklahoma City','None','nan','None','None','None','CNG','200-9','Private - Government only','None','35.473122','-97.551807','OK','735','City of Oklahoma City','None','E','621 N Pennsylvania Ave','73107')
# INSERT INTO charging_stations(access_code, city, ev_level1_evse_num, ev_level2_evse_num, ev_network, ev_network_web, ev_pricing, fuel_type_code, geocode_status, groups_with_access_code, intersection_directions, latitude, longitude, state, id, station_name, station_phone, status_code, street_address, zip) VALUES('public','Oklahoma City','None','nan','None','None','None','CNG','200-9','Public','NW 23rd St at Santa Fe.','35.494079','-97.511596','OK','36592','OnCue Express #101 - C-Store','405-557-1170','E','1 NW 23rd St','73103')
# INSERT INTO charging_stations(access_code, city, ev_level1_evse_num, ev_level2_evse_num, ev_network, ev_network_web, ev_pricing, fuel_type_code, geocode_status, groups_with_access_code, intersection_directions, latitude, longitude, state, id, station_name, station_phone, status_code, street_address, zip) VALUES('public','Oklahoma City','None','nan','None','None','None','E85','200-9','Public','NW 23rd St at Santa Fe.','35.494079','-97.511596','OK','105463','OnCue Express #101 - C-Store','405-557-1170','E','1 NW 23rd St','73103')
# INSERT INTO charging_stations(access_code, city, ev_level1_evse_num, ev_level2_evse_num, ev_network, ev_network_web, ev_pricing, fuel_type_code, geocode_status, groups_with_access_code, intersection_directions, latitude, longitude, state, id, station_name, station_phone, status_code, street_address, zip) VALUES('public','Oklahoma City','None','nan','None','None','None','CNG','200-9','Public','NE 36th & Santa Fe','35.508446','-97.511304','OK','71474','7-Eleven #23','405-208-4401','E','1 NE 36th St','73105')
# INSERT INTO charging_stations(access_code, city, ev_level1_evse_num, ev_level2_evse_num, ev_network, ev_network_web, ev_pricing, fuel_type_code, geocode_status, groups_with_access_code, intersection_directions, latitude, longitude, state, id, station_name, station_phone, status_code, street_address, zip) VALUES('public','Oklahoma City','None','2.0','None','None','Free','ELEC','200-8','Public','None','35.514833','-97.51194','OK','96937','Spiers New Technologies','405-605-8066','E','50 NE 42nd St','73105')
# INSERT INTO charging_stations(access_code, city, ev_level1_evse_num, ev_level2_evse_num, ev_network, ev_network_web, ev_pricing, fuel_type_code, geocode_status, groups_with_access_code, intersection_directions, latitude, longitude, state, id, station_name, station_phone, status_code, street_address, zip) VALUES('public','Oklahoma City','None','nan','None','None','None','E85','200-9','Public','None','35.42105','-97.508741','OK','91925','OnCue Express #113','405-632-0284','E','4413 S Shields Blvd','73129')
# INSERT INTO charging_stations(access_code, city, ev_level1_evse_num, ev_level2_evse_num, ev_network, ev_network_web, ev_pricing, fuel_type_code, geocode_status, groups_with_access_code, intersection_directions, latitude, longitude, state, id, station_name, station_phone, status_code, street_address, zip) VALUES('public','Oklahoma City','None','nan','None','None','None','CNG','200-9','Public - Credit card at all times','Reno Ave and N Portland Ave','35.464849','-97.584064','OK','44752','Conoco - Reno Partners','405-942-7528','E','3701 W Reno Ave','73107')
# INSERT INTO charging_stations(access_code, city, ev_level1_evse_num, ev_level2_evse_num, ev_network, ev_network_web, ev_pricing, fuel_type_code, geocode_status, groups_with_access_code, intersection_directions, latitude, longitude, state, id, station_name, station_phone, status_code, street_address, zip) VALUES('public','Oklahoma City','None','nan','None','None','None','E85','200-9','Public','None','35.479026','-97.583691','OK','91929','OnCue Express #125','405-948-3325','E','1001 N Portland Ave','73107')
# INSERT INTO charging_stations(access_code, city, ev_level1_evse_num, ev_level2_evse_num, ev_network, ev_network_web, ev_pricing, fuel_type_code, geocode_status, groups_with_access_code, intersection_directions, latitude, longitude, state, id, station_name, station_phone, status_code, street_address, zip) VALUES('public','Oklahoma City','None','nan','None','None','None','LPG','200-9','Public','None','35.472783','-97.585054','OK','35764','Pinnacle Propane','405-917-1850','E','601 N Portland Ave','73107')
# INSERT INTO charging_stations(access_code, city, ev_level1_evse_num, ev_level2_evse_num, ev_network, ev_network_web, ev_pricing, fuel_type_code, geocode_status, groups_with_access_code, intersection_directions, latitude, longitude, state, id, station_name, station_phone, status_code, street_address, zip) VALUES('private','Oklahoma City','None','nan','None','None','None','CNG','200-9','Private','None','35.520864','-97.51313','OK','739','Oklahoma Natural Gas - Northside Service Center','None','E','4901 N Santa Fe Ave','73118')
# INSERT INTO charging_stations(access_code, city, ev_level1_evse_num, ev_level2_evse_num, ev_network, ev_network_web, ev_pricing, fuel_type_code, geocode_status, groups_with_access_code, intersection_directions, latitude, longitude, state, id, station_name, station_phone, status_code, street_address, zip) VALUES('public','Oklahoma City','None','nan','None','None','None','CNG','200-9','Public - Credit card at all times','NW 36th St & N May Ave','35.507948','-97.564657','OK','73696','OnCue Express #119 - C-Store','405-338-8552','E','2837 NW 36th St','73112')
# INSERT INTO charging_stations(access_code, city, ev_level1_evse_num, ev_level2_evse_num, ev_network, ev_network_web, ev_pricing, fuel_type_code, geocode_status, groups_with_access_code, intersection_directions, latitude, longitude, state, id, station_name, station_phone, status_code, street_address, zip) VALUES('public','Oklahoma City','None','nan','None','None','None','E85','200-9','Public','NW 36th St & N May Ave','35.507948','-97.564657','OK','102564','OnCue Express #119 - C-Store','405-338-8552','E','2837 NW 36th St','73112')
# INSERT INTO charging_stations(access_code, city, ev_level1_evse_num, ev_level2_evse_num, ev_network, ev_network_web, ev_pricing, fuel_type_code, geocode_status, groups_with_access_code, intersection_directions, latitude, longitude, state, id, station_name, station_phone, status_code, street_address, zip) VALUES('private','Oklahoma City','None','nan','None','None','None','CNG','200-9','Private','None','35.455709','-97.585311','OK','737','United Parcel Service','None','E','901 S Portland Ave','73108')
# INSERT INTO charging_stations(access_code, city, ev_level1_evse_num, ev_level2_evse_num, ev_network, ev_network_web, ev_pricing, fuel_type_code, geocode_status, groups_with_access_code, intersection_directions, latitude, longitude, state, id, station_name, station_phone, status_code, street_address, zip) VALUES('private','Oklahoma City','None','nan','None','None','None','CNG','200-9','Private - Government only','At Portland Ave.','35.445459','-97.585727','OK','33117','City of Oklahoma City - Central Maintenance Facility','None','E','3738 SW 15th St','73108')
# INSERT INTO charging_stations(access_code, city, ev_level1_evse_num, ev_level2_evse_num, ev_network, ev_network_web, ev_pricing, fuel_type_code, geocode_status, groups_with_access_code, intersection_directions, latitude, longitude, state, id, station_name, station_phone, status_code, street_address, zip) VALUES('public','Oklahoma City','None','nan','None','None','None','LPG','200-9','Public','None','35.507159','-97.467311','OK','69625','U-Haul','405-424-5442','E','2500 36th St NE','73111')
